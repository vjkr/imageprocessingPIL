# %% [markdown]
# <a href="https://colab.research.google.com/github/vjkr/imageprocessingPIL/blob/main/imageprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lets learn basic image processing

# %%
# !git clone https://github.com/vjkr/imageprocessingPIL.git
# Out:
# Cloning into 'imageprocessingPIL'...
# remote: Enumerating objects: 30, done.
# remote: Counting objects: 100% (30/30), done.
# remote: Compressing objects: 100% (27/27), done.
# remote: Total 30 (delta 7), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (30/30), done.

# %%
from PIL import Image

# Opening the primary image (used in background)
img1 = Image.open(r"/content/imageprocessingPIL/images/vjkr320.jpg")

# Opening the secondary image (overlay image)
img2 = Image.open(r"/content/imageprocessingPIL/images/31Z97m.jpg")

# Pasting img2 image on top of img1
# starting at coordinates (0, 0)
img1.paste(img2, (0,0))

# Displaying the image
img1
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x320 at 0x7F16ED70F990>
